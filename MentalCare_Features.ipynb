# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaiyub/MentalCare/blob/main/MentalCare_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Row Data Analyze

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from google.colab import drive

# %%
df = pd.read_csv("/content/A Survey of Anxiety in Undergraduate Engineering Students.csv")
df.head(2)
# Out:
#                      Timestamp                       Username  \
# 0  2023/11/25 2:23:15 PM GMT+6         siam15-4442@diu.edu.bd
# 1  2023/11/25 2:24:26 PM GMT+6  hossain23105101171@diu.edu.bd
#
#     What's your name? How old are you(in year)?  \
# 0  Akibul Islam Siam                      18-30
# 1  Md.Sabbir HOSSAIN                      18-30
#
#   What is your gender identity?   \
# 0                           Male
# 1                           Male
#
#   Which types of University are you studying in? Name of the Department  \
# 0                                        Private                    CSE
# 1                                        Private                    CSE
#
#   Please indicate your current marital status Employment Status?  \
# 0                                      Single            Student
# 1                                      Single            Student
#
#   Total sleeping time per day(hours)?  ...  \
# 0                                 6-8  ...
# ...

# %%
 df.columns
# Out:
# Index(['Timestamp', 'Username', 'What's your name?',
#        'How old are you(in year)?', 'What is your gender identity? ',
#        'Which types of University are you studying in?',
#        'Name of the Department', 'Please indicate your current marital status',
#        'Employment Status?', 'Total sleeping time per day(hours)?',
#        'Social media Usage per day(hours)?', 'Daily hangout time(hours)?',
#        'Daily Academic Activities(Hours)',
#        'Is your family financially stable?', 'Do you have family Stress?',
#        'Do you have carrier stress?', 'Feeling nervous, anxious, or on edge',
#        'Not being able to stop or control worrying',
#        'Worrying too much about different things', 'Trouble relaxing',
#        'Being so restless that it is hard to sit still',
#        'Becoming easily annoyed or irritable',
#        'Feeling afraid, as if something awful might happen',
#        'Have you ever went to a psychologist?',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           738 non-null    object
#  1   Username                                            738 non-null    object
#  2   What's your name?                                   737 non-null    object
#  3   How old are you(in year)?                           738 non-null    object
#  4   What is your gender identity?                       738 non-null    object
#  5   Which types of University are you studying in?      738 non-null    object
#  6   Name of the Department                              738 non-null    object
#  7   Please indicate your current marital status         738 non-null    object
# ...

# %%
df.shape
# Out:
# (738, 28)

# %%
df.isnull().sum()
# Out:
# Timestamp                                             0
# Username                                              0
# What's your name?                                     1
# How old are you(in year)?                             0
# What is your gender identity?                         0
# Which types of University are you studying in?        0
# Name of the Department                                0
# Please indicate your current marital status           0
# Employment Status?                                    0
# Total sleeping time per day(hours)?                   0
# Social media Usage per day(hours)?                    0
# Daily hangout time(hours)?                            0
# Daily Academic Activities(Hours)                      0
# Is your family financially stable?                    0
# Do you have family Stress?                            0
# Do you have carrier stress?                           0
# Feeling nervous, anxious, or on edge                  0
# ...

# %%
df.drop(["Timestamp","Username", "What's your name?"], axis = 1, inplace = True)
df.head(3)
# Out:
#   How old are you(in year)? What is your gender identity?   \
# 0                     18-30                           Male
# 1                     18-30                           Male
# 2                     18-30                           Male
#
#   Which types of University are you studying in? Name of the Department  \
# 0                                        Private                    CSE
# 1                                        Private                    CSE
# 2                                        Private                    CSE
#
#   Please indicate your current marital status Employment Status?  \
# 0                                      Single            Student
# 1                                      Single            Student
# 2                                      Single            Student
#
#   Total sleeping time per day(hours)? Social media Usage per day(hours)?  \
# 0                                 6-8                                4-6
# ...

# %% [markdown]
# # Conversion

# %%
df.columns
# Out:
# Index(['How old are you(in year)?', 'What is your gender identity? ',
#        'Which types of University are you studying in?',
#        'Name of the Department', 'Please indicate your current marital status',
#        'Employment Status?', 'Total sleeping time per day(hours)?',
#        'Social media Usage per day(hours)?', 'Daily hangout time(hours)?',
#        'Daily Academic Activities(Hours)',
#        'Is your family financially stable?', 'Do you have family Stress?',
#        'Do you have carrier stress?', 'Feeling nervous, anxious, or on edge',
#        'Not being able to stop or control worrying',
#        'Worrying too much about different things', 'Trouble relaxing',
#        'Being so restless that it is hard to sit still',
#        'Becoming easily annoyed or irritable',
#        'Feeling afraid, as if something awful might happen',
#        'Have you ever went to a psychologist?',
#        'Are you ever experiencing suicidal thoughts?', 'Confidence level?',
# ...

# %%
df["Do you feel anxious?"].unique()
# Out:
# array(['No', 'Yes', 'Yes;No'], dtype=object)

# %%
df["Do you feel anxious?"].value_counts()
# Out:
# Do you feel anxious?
# Yes       400
# No        332
# Yes;No      6
# Name: count, dtype: int64

# %%
df["anxiety"] = df["Do you feel anxious?"].map({"Yes": 1, "No": 2, "Yes;No": 1})

# %%
df["anxiety"].dtypes
# Out:
# dtype('int64')

# %%
df.head(2)
# Out:
#   How old are you(in year)? What is your gender identity?   \
# 0                     18-30                           Male
# 1                     18-30                           Male
#
#   Which types of University are you studying in? Name of the Department  \
# 0                                        Private                    CSE
# 1                                        Private                    CSE
#
#   Please indicate your current marital status Employment Status?  \
# 0                                      Single            Student
# 1                                      Single            Student
#
#   Total sleeping time per day(hours)? Social media Usage per day(hours)?  \
# 0                                 6-8                                4-6
# 1                                 6-8                                3-4
#
#   Daily hangout time(hours)? Daily Academic Activities(Hours)  ...  \
# 0                        1-2                              1-2  ...
# ...

# %% [markdown]
# # New DataFrame

# %%
df['age group'] = df['How old are you(in year)?'].map({'Under 18': 0, '18-30': 1})
df['gender'] = df['What is your gender identity? '].map({'Male': 1, 'Female': 0})
df["university"] = df["Which types of University are you studying in?"].map({"Private": 1, "Public": 2, "others": 3})
df["department"] = df["Name of the Department"].map({"CSE": 2, "ICE": 1})
df["marital status"] = df["Please indicate your current marital status"].map({"Single": 1, "In a Relationship": 2, "Married": 3})
df["employment status"] = df["Employment Status?"].map({"Student": 1, "Part-time": 2, "Full time": 3})
df["sleeping cycle"] = df["Total sleeping time per day(hours)?"].map({"Below 6": 1, "6-8": 2, "Above 8": 3})
df["social media screening"] = df["Social media Usage per day(hours)?"].map({"Below 1": 1, "1-2": 2, "3-4": 3, "4-6": 4, "Above 6": 5})
df["hangout period"] = df["Daily hangout time(hours)?"].map({"Below 1": 1, "1-2": 2, "3-4": 3, "5-6": 4, "Above 6": 5})
df["academic activity"] = df["Daily Academic Activities(Hours)"].map({"Below 1": 1, "1-2": 2, "3-4": 3, "5-6": 4, "Above 6": 5})
df["financial status"] = df["Is your family financially stable?"].map({"Very Stable": 1, "Somewhat Stable": 2, "Neutral": 3, "Somewhat Unstable": 4, "Very Unstable": 5})
df["family stress"] = df["Do you have family Stress?"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["carrier stress"] = df["Do you have carrier stress?"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["nervous level"] = df["Feeling nervous, anxious, or on edge"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["worries level"] = df["Not being able to stop or control worrying"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4, "Not at All;Several Days": 1})
df["things level"] = df["Worrying too much about different things"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["trouble relaxing"] = df["Trouble relaxing"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["restless level"] = df["Being so restless that it is hard to sit still"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["irritation level"] = df["Becoming easily annoyed or irritable"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4, "Not at All;Several Days": 1})
df["fear level"] = df["Feeling afraid, as if something awful might happen"].map({"Not at All": 1, "Several Days": 2, "More Than Half The Days": 3, "Nearly Every Day": 4})
df["counsel status"] = df["Have you ever went to a psychologist?"].map({"No": 0, "Yes": 1})
df["suicidal experience"] = df["Are you ever experiencing suicidal thoughts?"].map({"No": 0, "Yes": 1})
df["confidence level"] = df["Confidence level?"].map({"No Confidence": 1, "Low": 2, "Medium": 3, "High": 4})
df["study desire"] = df["How would you rate your desire to study this week?"].map({"No desire to Study": 1, "slightly Desire": 2, "Desire to Study": 3, "Very Motivated to study": 4})
df["anxiety status"] = df["Do you feel anxious?"].map({"Yes": 1, "No": 2, "Yes;No": 1})

# %%
new_df = df[['age group', 'gender', 'university', 'department', 'marital status', 'employment status', 'sleeping cycle',
             'social media screening', 'hangout period', 'academic activity', 'financial status', 'family stress',
             'carrier stress', 'nervous level', 'worries level', 'things level', 'trouble relaxing', 'restless level',
             'irritation level', 'fear level' , 'counsel status', 'suicidal experience', 'confidence level', 'study desire',
             'anxiety status']]
new_df.head(10)
# Out:
#    age group  gender  university  department  marital status  \
# 0          1       1           1           2               1
# 1          1       1           1           2               1
# 2          1       1           1           2               1
# 3          1       1           1           2               1
# 4          1       1           1           2               1
# 5          1       1           1           2               1
# 6          1       1           1           2               1
# 7          1       0           1           2               1
# 8          1       1           1           2               1
# 9          1       0           1           2               3
#
#    employment status  sleeping cycle  social media screening  hangout period  \
# 0                  1               2                       4               2
# 1                  1               2                       3               2
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age group               738 non-null    int64
#  1   gender                  738 non-null    int64
#  2   university              738 non-null    int64
#  3   department              738 non-null    int64
#  4   marital status          738 non-null    int64
#  5   employment status       738 non-null    int64
#  6   sleeping cycle          738 non-null    int64
#  7   social media screening  738 non-null    int64
#  8   hangout period          738 non-null    int64
#  9   academic activity       738 non-null    int64
#  10  financial status        738 non-null    int64
#  11  family stress           738 non-null    int64
#  12  carrier stress          738 non-null    int64
#  13  nervous level           738 non-null    int64
# ...

# %%
new_df.to_csv('new_df.csv', index=False)
